# %% [markdown]
# <a href="https://colab.research.google.com/github/iAryan99/Speech-Signal-Processing-for-ML/blob/main/Fourier_Transform_using_Complex_Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cmath
import matplotlib.pyplot as plt
import numpy as np

# %%
def create_signal(frequency, time):
    sin1 = np.sin(2 * np.pi * (1 * frequency * time))
    sin2 = np.sin(2 * np.pi * (2 * frequency * time))
    sin3 = np.sin(2 * np.pi * (3 * frequency * time))

    return sin1 + sin2 + sin3

# %%
def calculate_centre_of_gravity(mult_signal):
    x_centre = np.mean([x.real for x in mult_signal])
    y_centre = np.mean([x.imag for x in mult_signal])
    return x_centre, y_centre

# %%
def calculate_sum(mult_signal):
    x_sum = np.sum([x.real for x in mult_signal])
    y_sum = np.sum([x.imag for x in mult_signal])
    return x_sum, y_sum

# %%
def create_pure_tone(frequency, time):
    angle = -2 * np.pi * frequency * time
    return np.cos(angle) + 1j * np.sin(angle)

# %%
def plot_fourier_transform(pure_tone_frequency, 
                           signal_frequency, 
                           time, 
                           plot_centre_of_gravity = False,
                           plot_sum = False):
    
    # create sinusoid and signal
    pure_tone = create_pure_tone(pure_tone_frequency, time)
    signal = create_signal(signal_frequency, time)
    
    # multiply pure tone and signal
    mult_signal = pure_tone * signal
    
    X = [x.real for x in mult_signal]
    Y = [x.imag for x in mult_signal]

    plt.figure(figsize = (15, 10))
    plt.plot(X, Y)

    # calculate and plot centre of gravity
    if plot_centre_of_gravity:
        centre_of_gravity = calculate_centre_of_gravity(mult_signal)
        plt.plot([centre_of_gravity[0]], [centre_of_gravity[1]], marker = 'o', markersize = 10, color = "red")


    # calculate and plot sum 
    if plot_sum:
        integral = calculate_sum(mult_signal)
        plt.plot([integral[0]], [integral[1]], marker = 'o', markersize = 10, color = "green")

    
    # set origin axes
    ax = plt.gca()
    ax.grid(True)
    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')

    if not plot_sum:
        plt.xlim(-3, 3)
        plt.ylim(-3, 3)

    plt.show()

# %%
def plot_signal(signal, time):
    plt.figure(figsize = (15, 10))
    plt.plot(signal, time)
    plt.xlabel("Time")
    plt.ylabel("Intensity")
    plt.show()

# %%
time = np.linspace(0, 10, 10000)
signal = create_signal(frequency = 1, time = time)
plot_signal(time, signal)

# %%
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 1,
                       signal_frequency = 1,
                       time = time)

#The o/p shows the Complex Plane

# %%
#Changing the Pure Tone Frq from 1Hz to 1.1Hz
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time)

#How do we get this o/p with a slight change of 0.1Hz
#The o/p is constituted through iterations of various time values as shown in the next couple of code cells

# %%
#Changing the Time variable to 1
time = np.linspace(0, 1, 10000)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time)

# %%
#Changing the time variable to 2
time = np.linspace(0, 2, 10000)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time)

# %%
#Changing the time variable to 5
time = np.linspace(0, 5, 10000)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time)

# %%
#Now changing the Pure Tone Frq value to 2 and Time is reset to 10
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 2,
                       signal_frequency = 1,
                       time = time)

# %%
#Further changing the Pure Tone Frq value to 3
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 3,
                       signal_frequency = 1,
                       time = time)

# %%
#Now changing the Pure Tone Frq value to 3.1
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 3.1,
                       signal_frequency = 1,
                       time = time)

#If frq values are in whole numbers that are present in the original sound, then we have a more stable o/p like the previous cell

# %%
#Now plotting Centre of Gravity for Pure Tone Frq value 3
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 3,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True)

# %%
#But for Pure Tone Frq value 3.1
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 3.1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True)

#This explains that the CoG value adds up all the +ve & -ve values

# %%
#For Pure Tone Frq value 1
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True)

#The value of CoG is a complex number which is the Fourier Transform Coefficient and has information about the phase (angle between the real axis and CoG) and magnitude (distance of CoG from origin)

# %%
#Now averaging the 10000 steps
time = np.linspace(0, 10, 10000)
plot_fourier_transform(pure_tone_frequency = 1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True,
                       plot_sum = True)

# %%
#Changing Time value to 1 and number of steps to 10
time = np.linspace(0, 1, 10)
plot_fourier_transform(pure_tone_frequency = 1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True,
                       plot_sum = True)

#CoG value is near -0.5 and the Average is around -5, i.e., 10 no. of steps times the CoG value

# %%
#Changing Time to 10, Steps to 1000, and Pure Tone Frq to 1.1
time = np.linspace(0, 10, 1000)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = True,
                       plot_sum = True)

#Both CoG and Average lie on the origin

# %%
#@title Default title text
def plot_fourier_transform(pure_tone_frequency, 
                           signal_frequency, 
                           time, 
                           plot_centre_of_gravity = False,
                           plot_sum = False):
    
    # create sinusoid and signal
    pure_tone = create_pure_tone(pure_tone_frequency, time)
    signal = create_signal(signal_frequency, time)
    
    # multiply pure tone and signal
    mult_signal = pure_tone * signal
    
    X = [x.real for x in mult_signal]
    Y = [x.imag for x in mult_signal]

    plt.figure(figsize = (15, 10))
    plt.plot(X, Y, 'o')

    # calculate and plot centre of gravity
    if plot_centre_of_gravity:
        centre_of_gravity = calculate_centre_of_gravity(mult_signal)
        plt.plot([centre_of_gravity[0]], [centre_of_gravity[1]], marker = 'o', markersize = 10, color = "red")


    # calculate and plot sum 
    if plot_sum:
        integral = calculate_sum(mult_signal)
        plt.plot([integral[0]], [integral[1]], marker = 'o', markersize = 10, color = "green")

    
    # set origin axes
    ax = plt.gca()
    ax.grid(True)
    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_color('none')

    if not plot_sum:
        plt.xlim(-3, 3)
        plt.ylim(-3, 3)

    plt.show()

# %%
#Taking 10 steps for the 1 sec interval
time = np.linspace(0, 1, 10)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = False,
                       plot_sum = False)

# %%
#Taking 100 steps for the 1 sec interval
time = np.linspace(0, 1, 100)
plot_fourier_transform(pure_tone_frequency = 1.1,
                       signal_frequency = 1,
                       time = time,
                       plot_centre_of_gravity = False,
                       plot_sum = False)
